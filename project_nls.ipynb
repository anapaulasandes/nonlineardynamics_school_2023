# %% [markdown]
# # Project Nonlinear school 2023

# %% [markdown]
# Students: Isabelle Melo, Bruna Carvalho, Luz Durán, Ana Paula Sandes

# %%
from main import main

main(800,200)

# main(ni,ne)
# Out:
# ([5,
#   6,
#   6,
#   6,
#   6,
#   6,
#   7,
#   7,
#   7,
#   7,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   9,
#   10,
#   10,
#   10,
#   10,
#   10,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   13,
#   13,
#   13,
#   13,
#   13,
#   13,
#   13,
#   13,
#   13,
#   13,
#   13,
#   13,
#   13,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   17,
#   17,
#   17,
#   17,
#   17,
#   17,
#   17,
#   17,
#   17,
#   17,
# ...

# %%
len(main(800,200))
# Out:
# 2

# %%
times, spikes = main(800,200)

print(times)
# Out:
# [6, 6, 6, 6, 6, 6, 8, 9, 9, 9, 9, 9, 9, 10, 10, 10, 11, 11, 11, 11, 11, 11, 12, 12, 12, 12, 12, 12, 12, 13, 13, 13, 13, 13, 13, 13, 13, 14, 14, 14, 14, 14, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24
# ...

# %%
print(spikes)
# Out:
# [113, 169, 261, 446, 476, 512, 345, 214, 267, 289, 690, 737, 962, 274, 384, 613, 282, 350, 423, 518, 547, 678, 54, 83, 147, 300, 567, 695, 703, 225, 541, 685, 796, 898, 923, 969, 978, 57, 64, 95, 829, 886, 41, 110, 159, 167, 511, 531, 554, 594, 667, 700, 745, 810, 855, 883, 147, 199, 254, 262, 340, 407, 460, 592, 617, 691, 709, 830, 841, 917, 927, 20, 72, 83, 92, 118, 119, 381, 387, 465, 583, 642, 791, 925, 983, 56, 110, 327, 342, 370, 480, 654, 714, 738, 882, 914, 976, 981, 18, 78, 82, 122, 139, 148, 151, 201, 329, 410, 438, 537, 573, 630, 865, 866, 902, 990, 996, 17, 43, 55, 65, 365, 432, 459, 516, 549, 551, 615, 625, 652, 701, 702, 707, 727, 796, 818, 869, 934, 965, 980, 991, 6, 36, 62, 76, 124, 160, 180, 181, 292, 346, 364, 369, 455, 491, 556, 606, 648, 679, 715, 773, 809, 823, 824, 859, 900, 939, 950, 985, 992, 28, 85, 138, 202, 207, 218, 227, 297, 358, 374, 403, 415, 464, 546, 591, 598, 704, 782, 803, 806, 822, 851, 897, 916, 933, 959, 995, 8, 43, 52, 78, 81, 150, 198, 268, 303
# ...

# %%
ni = [800, 900, 1000]

ne = [200, 400, 600, 800, 1000]

# %%
neuron_dict = {}

for i, n_i in enumerate(ni):
    for j, n in enumerate(ne):
        neuron_dict[i,j] = n_i, n

list_spikes= list(neuron_dict.values())

list_spikes
# Out:
# [(800, 200),
#  (800, 400),
#  (800, 600),
#  (800, 800),
#  (800, 1000),
#  (900, 200),
#  (900, 400),
#  (900, 600),
#  (900, 800),
#  (900, 1000),
#  (1000, 200),
#  (1000, 400),
#  (1000, 600),
#  (1000, 800),
#  (1000, 1000)]

# %%
import matplotlib.pyplot as plt

# fixo um ni e vario os nes


#regularization = [0.0001, 0.005, 0.1, 0.5]

#coefs = ['w0','w1','w2','w3','w4','w5','w6','w7','w8','w9']

fig, axs = plt.subplots(1,5)
fig.set_size_inches(20, 20)
ind = 0

for ax in axs.flat:

    times, spikes = main(ni[ind],ne[ind])

    ax.set_title(f'Ni={ni[ind]}, Ne={ne[ind]}')

    ax.plot(times,spikes, ',k')
        
    ind += 1

# %%
for i in range(0, len(list_spikes)):
    ni = list_spikes[i][0]
    ne = list_spikes[i][1]
    
    fig, axs = plt.subplots(1,5)
    fig.set_size_inches(20, 20)
    ind = 0

    for ax in axs.flat:

        times, spikes = main(ni,ne)

        ax.set_title(f'Ni={ni[ind]}, Ne={ne[ind]}')

        ax.plot(times,spikes, ',k')
            
        ind += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 13
#       9 for ax in axs.flat:
#      11     times, spikes = main(ni,ne)
# ---> 13     ax.set_title(f'Ni={ni[ind]}, Ne={ne[ind]}')
#      15     ax.plot(times,spikes, ',k')
#      17     ind += 1
#
# TypeError: 'int' object is not subscriptable
