# %%
from src.ichikevich import simulate_network
import matplotlib.pyplot as plt

# %% [markdown]
# Increasing Ne Network Size

# %%
Ne_list = list(range(1000,1001 + 600,100))

# %%
for i in Ne_list:
    
    simulate_network(i, 100, 0.6, 1, 0.5)
